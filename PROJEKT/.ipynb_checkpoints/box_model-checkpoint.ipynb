# %%
import INTFUN
from importlib import reload
from INTFUN import Integrator
reload(INTFUN)
from collections import namedtuple
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
from importlib import reload
reload(Integrator)
from collections import namedtuple
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd


class Integ59(Integrator):

    def set_yinit(self):
        #
        # read in 'albedo_white chi S0 L albedo_black R albedo_ground'
        #
        uservars = namedtuple('uservars', self.config['uservars'].keys())
        self.uservars = uservars(**self.config['uservars'])
        #
        # read in 'whiteconc blackconc'
        #
        initvars = namedtuple('initvars', self.config['initvars'].keys())
        self.initvars = initvars(**self.config['initvars'])
        self.yinit = np.array(
            [self.initvars.seaDMS,
             self.initvars.airDMS,
             self.initvars.CCN,
             self.initvars.COD,
             self.initvars.albedo,
             self.initvars.PAR,
             self.initvars.primprod])       
        self.nvars = len(self.yinit)
        return None

    def __init__(self, coeff_file_name):
        super().__init__(coeff_file_name)
        self.set_yinit()

    def find_temp(self, yvals):
        """
            Calculate the temperatures over the white and black daisies
            and the planetary equilibrium temperature given the daisy fractions
            
            input:  yvals -- array of dimension [2] with the white [0] and black [1]
                    daisy fractiion
            output:  white temperature (K), black temperature (K), equilibrium temperature (K)
        """
        sigma = 5.67e-8  # Stefan Boltzman constant W/m^2/K^4
        user = self.uservars
        bare = 1.0 - yvals[0] - yvals[1]
        albedo_p = bare * user.albedo_ground + \
            yvals[0] * user.albedo_white + yvals[1] * user.albedo_black
        Te_4 = user.S0 / 4.0 * user.L * (1.0 - albedo_p) / sigma
        temp_e = Te_4**0.25
        eta = user.R * user.L* user.S0 / (4.0 * sigma)
        temp_b = (eta * (albedo_p - user.albedo_black) + Te_4)**0.25
        temp_w = (eta * (albedo_p - user.albedo_white) + Te_4)**0.25
        return (temp_w, temp_b, temp_e)

    def derivs5(self, y, t,ice):
        print(ice)
        user = self.uservars

        f = np.empty_like(y)

        #sea DMS
        f[0] = .1#y[0] 
        #air DMS
        f[1] = .1#y[0]
        #CCN
        f[2] = y[2]
        #COD
        f[3] = y[3] 
        #albedo
        f[4] = 0
        #PAR
        f[5] = y[5] 
        #primprod
        f[6] = y[6]

        
        return f
    

theSolver = Integ59('adapt13.yaml')
timeVals,yVals,errorList=theSolver.timeloop5fixed()


yvals=pd.DataFrame.from_records(yVals,columns=['white','black','rabbit','fox','kitten','kitten','kitten'])

thefig,theAx=plt.subplots(1,1)

points,=theAx.plot(timeVals,yvals['white'],'-b+',label='white daisies')
points.set_markersize(12)
theLine1,=theAx.plot(timeVals,yvals['black'],'--ko',label='black daisies')
theLine2,=theAx.plot(timeVals,yvals['rabbit'],'--ro',label='rabbits')
theLine2,=theAx.plot(timeVals,yvals['fox'],'--go',label='foxes')
theAx.set_title('Rabbits, Daisies, Foxes in Harmony')
theAx.set_xlabel('time')
theAx.set_ylim([0,200])
theAx.set_xlim([0,10])
theAx.set_ylabel('fractional coverage')
out=theAx.legend(loc='best')
# Out:
# timerrr*
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d9eade387fe4> in <module>()
#      84
#      85 theSolver = Integ59('adapt13.yaml')
# ---> 86 timeVals,yVals,errorList=theSolver.timeloop5fixed()
#      87
#      88
#
# /Users/alena/Sync/numeric/PROJEKT/INTFUN.py in timeloop5fixed(self)
#     266         timeSteps = np.arange(t.tstart, t.tend, t.dt)
#     267         print(timeSteps)
# --> 268         #for theTime in timeSteps[:-1]:
#     269         #    yold, yError, newTime = self.rkckODE5(yold, theTime, t.dt)
#     270         #    yvals.append(yold)
#
# /Users/alena/Sync/numeric/PROJEKT/INTFUN.py in rkckODE5(self, yold, timeStep, deltaT)
#      84
#      85         print(timeStep)
# ---> 86         ice = self.met_forcing(timeStep)
#      87         a, c1, c2, b = self.rkckConsts
#      88         i = self.initvars
#
# TypeError: met_forcing() takes 1 positional argument but 2 were given

# %%
import numlabs.lab5.lab5_funs
from importlib import reload
reload(numlabs.lab5.lab5_funs)
from numlabs.lab5.lab5_funs import Integrator
from collections import namedtuple
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd


class Integ59(Integrator):

    def set_yinit(self):
        #
        # read in 'albedo_white chi S0 L albedo_black R albedo_ground'
        #
        uservars = namedtuple('uservars', self.config['uservars'].keys())
        self.uservars = uservars(**self.config['uservars'])
        #
        # read in 'whiteconc blackconc'
        #
        initvars = namedtuple('initvars', self.config['initvars'].keys())
        self.initvars = initvars(**self.config['initvars'])
        self.yinit = np.array(
            [self.initvars.seaDMS,
             self.initvars.airDMS,
             self.initvars.CCN,
             self.initvars.COD,
             self.initvars.albedo,
             self.initvars.primprod])
        
        self.nvars = len(self.yinit)
        return None

    def __init__(self, coeff_file_name):
        super().__init__(coeff_file_name)
        self.set_yinit()

    def find_temp(self, yvals):
        """
            Calculate the temperatures over the white and black daisies
            and the planetary equilibrium temperature given the daisy fractions
            
            input:  yvals -- array of dimension [2] with the white [0] and black [1]
                    daisy fractiion
            output:  white temperature (K), black temperature (K), equilibrium temperature (K)
        """
        sigma = 5.67e-8  # Stefan Boltzman constant W/m^2/K^4
        user = self.uservars
        #bare = 1.0 - yvals[0] - yvals[1]
        albedo_p =1 # bare * user.albedo_ground + \
        #   yvals[0] * user.albedo_white + yvals[1] * user.albedo_black
        Te_4 = user.S0 / 4.0 * user.L * (1.0 - albedo_p) / sigma
        temp_e = Te_4**0.25
        eta = user.R * user.L* user.S0 / (4.0 * sigma)
        temp_b = 1#(eta * (albedo_p - user.albedo_black) + Te_4)**0.25
        temp_w = 1 #(eta * (albedo_p - user.albedo_white) + Te_4)**0.25
        return (temp_w, temp_b, temp_e)

    def derivs5(self, y, t):
        """y[0]=fraction white daisies
           y[1]=fraction black daisies
           no feedback between daisies and
           albedo_p (set to ground albedo)
        """
        temp_w, temp_b, temp_e = self.find_temp(y)

        if(temp_b >= 277.5 and temp_b <= 312.5):
            beta_b = 1.0 - 0.003265 * (295.0 - temp_b)**2.0
        else:
            beta_b = 0.0

        if(temp_w >= 277.5 and temp_w <= 312.5):
            beta_w = 1.0 - 0.003265 * (295.0 - temp_w)**2.0
        else:
            beta_w = 0.0
            
        beta_r = 0.59
        beta_f = .7
        
        user = self.uservars
        


        f[0] = y[0] * .1
        f[1] = y[1] * .1
        f[2] = y[2] * .1
        f[3] = y[3] * .1
        f[4] = y[4] * .1
        f[5] = y[5] * .1
    
        
        return f
    

theSolver = Integ59('adapt13.yaml')
timeVals,yVals,errorList=theSolver.timeloop5Err()

yvals=pd.DataFrame.from_records(yVals,columns=['seaDMS','black','rabbit','fox','kitten','kitten2'])

thefig,theAx=plt.subplots(1,1)

points,=theAx.plot(timeVals,yvals['seaDMS'],'-b+',label='white daisies')
points.set_markersize(12)
theLine1,=theAx.plot(timeVals,yvals['black'],'--ko',label='black daisies')
theLine2,=theAx.plot(timeVals,yvals['rabbit'],'--ro',label='rabbits')
theLine2,=theAx.plot(timeVals,yvals['fox'],'--go',label='foxes')
theAx.set_title('Rabbits, Daisies, Foxes in Harmony')
theAx.set_xlabel('time')
theAx.set_ylabel('fractional coverage')
out=theAx.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-501e7ffb747e> in <module>()
#      96
#      97 theSolver = Integ59('adapt13.yaml')
# ---> 98 timeVals,yVals,errorList=theSolver.timeloop5Err()
#      99
#     100 yvals=pd.DataFrame.from_records(yVals,columns=['seaDMS','black','rabbit','fox','kitten','kitten2'])
#
# /Users/alena/Sync/numeric/numlabs/lab5/lab5_funs.py in timeloop5Err(self)
#     154                 # try a timestep, we may need to reverse this
#     155                 #
# --> 156                 ynew, yerror, timeStep = self.rkckODE5(yold, oldTime, olddt)
#     157                 # print("try a step: : ", ynew)
#     158                 #
#
# /Users/alena/Sync/numeric/numlabs/lab5/lab5_funs.py in rkckODE5(self, yold, timeStep, deltaT)
#      82         estError = np.zeros_like(yold)
#      83         # vector k1 in lab4 equation 3.9
# ---> 84         derivArray[0, :] = self.derivs5(yold, timeStep)[:]
#      85
#      86         # calculate step
#
# <ipython-input-23-501e7ffb747e> in derivs5(self, y, t)
#      84
#      85
# ---> 86         f[0] = y[0] * .1
#      87         f[1] = y[1] * .1
#      88         f[2] = y[2] * .1
#
# NameError: name 'f' is not defined
